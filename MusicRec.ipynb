# %%
import pandas as pd
import numpy as np

# %%
song_data=pd.read_csv('SpotifyFeatures.csv')

# %%
song_data.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
song_data.sort_values('track_name')
# Out:
#           genre          artist_name  \
# 58300     Opera         Maria Callas
# 32571     Anime         Yuki Hayashi
# 89661   Hip-Hop         Rae Sremmurd
# 121128      Rap         Rae Sremmurd
# 142359    Indie  The Gaslight Anthem
# ...         ...                  ...
# 150871      Pop                 GOT7
# 219320    World        Park Hyo Shin
# 149889      Pop                 Day6
# 220337    World         Lee Moon Sae
# 219463    World        Sung Si-kyung
#
#                                                track_name  \
# 58300   " La Traviata " : Amami Alfredo (Act II) - Dig...
# 32571                                                "1点"
# 89661                                   "42" - From SR3MM
# 121128                                  "42" - From SR3MM
# 142359                                               "45"
# ...                                                   ...
# 150871                                    하드캐리 Hard Carry
# ...

# %%
song_data.count()
# Out:
# genre               232725
# artist_name         232725
# track_name          232725
# track_id            232725
# popularity          232725
# acousticness        232725
# danceability        232725
# duration_ms         232725
# energy              232725
# instrumentalness    232725
# key                 232725
# liveness            232725
# loudness            232725
# mode                232725
# speechiness         232725
# tempo               232725
# time_signature      232725
# valence             232725
# dtype: int64

# %%
song_data.duplicated('track_name')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 232720     True
# 232721    False
# 232722     True
# 232723     True
# 232724    False
# Length: 232725, dtype: bool

# %%
ss=song_data

# %%
ss.count()
# Out:
# genre               232725
# artist_name         232725
# track_name          232725
# track_id            232725
# popularity          232725
# acousticness        232725
# danceability        232725
# duration_ms         232725
# energy              232725
# instrumentalness    232725
# key                 232725
# liveness            232725
# loudness            232725
# mode                232725
# speechiness         232725
# tempo               232725
# time_signature      232725
# valence             232725
# dtype: int64

# %%
ssclean=ss.drop_duplicates(subset='track_name')

# %%
ssclean.count()
# Out:
# genre               148615
# artist_name         148615
# track_name          148615
# track_id            148615
# popularity          148615
# acousticness        148615
# danceability        148615
# duration_ms         148615
# energy              148615
# instrumentalness    148615
# key                 148615
# liveness            148615
# loudness            148615
# mode                148615
# speechiness         148615
# tempo               148615
# time_signature      148615
# valence             148615
# dtype: int64

# %%
ssclean.head(n=20)
# Out:
#     genre           artist_name  \
# 0   Movie        Henri Salvador
# 1   Movie     Martin & les fées
# 2   Movie       Joseph Williams
# 3   Movie        Henri Salvador
# 4   Movie          Fabien Nataf
# 5   Movie        Henri Salvador
# 6   Movie     Martin & les fées
# 7   Movie           Laura Mayne
# 8   Movie                Chorus
# 9   Movie   Le Club des Juniors
# 10  Movie     Leopold Stokowski
# 11  Movie          Randy Newman
# 12  Movie  Idoles De La Musique
# 13  Movie                Chorus
# 14  Movie    Richard M. Sherman
# 15  Movie           Michel Roux
# 16  Movie    Jean Claude Corbel
# 17  Movie         Bernard Minet
# 18  Movie        Henri Salvador
# 19  Movie                Amalya
#
#                                            track_name                track_id  \
# 0                         C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV
# 1                    Perdu d'avance (par Gad Elmaleh)  0BjC1NfoEOOusryehmNudP
# ...

# %%
ssclean=ssclean.sort_values('track_name')

# %%
ssclean.head()
# Out:
#           genre          artist_name  \
# 58300     Opera         Maria Callas
# 32571     Anime         Yuki Hayashi
# 89661   Hip-Hop         Rae Sremmurd
# 142359    Indie  The Gaslight Anthem
# 33675     Anime         Yuki Hayashi
#
#                                                track_name  \
# 58300   " La Traviata " : Amami Alfredo (Act II) - Dig...
# 32571                                                "1点"
# 89661                                   "42" - From SR3MM
# 142359                                               "45"
# 33675                                       "6人で(強い方が強い)"
#
#                       track_id  popularity  acousticness  danceability  \
# 58300   0wtpkz93wATDkUExJVuXEl          31      0.993000         0.364
# 32571   7JkDONXIbcKUQ7QzlLBumL          23      0.025000         0.250
# 89661   5lf91lPnGKtIqsgmG1z8Ip          53      0.002750         0.968
# 142359  25Sd73fleKUVPNqITPZkn1          48      0.000696         0.315
# ...

# %%
ssclean.tail()
# Out:
#         genre    artist_name                      track_name  \
# 150871    Pop           GOT7                 하드캐리 Hard Carry
# 219320  World  Park Hyo Shin  해줄 수 없는 일 Haejul Su Eomneun Il
# 149889    Pop           Day6         행복했던 날들이었다 days gone by
# 220337  World   Lee Moon Sae                             휘파람
# 219463  World  Sung Si-kyung                              희재
#
#                       track_id  popularity  acousticness  danceability  \
# 150871  7Cd4glTUgV0vr0DBncEg8S          63       0.01480         0.700
# 219320  3Kk075LR7Bj2bUH1mB3TIZ          30       0.72900         0.332
# 149889  3TE3SbiWrm69WyUl8BlZEV          64       0.00211         0.613
# 220337  3G9dGrDJAPTDtJCGk8VF5i          27       0.51300         0.521
# 219463  3Ijb2UjPpI9RW6eSvR4Eve          34       0.43800         0.460
#
#         duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 150871       193579   0.873          0.000000  C#     0.343    -2.901  Major
# ...

# %%
spop=ssclean.sort_values('popularity')

# %%
spop.tail(n=10)
# Out:
#           genre    artist_name                                     track_name  \
# 107812      Pop     Marshmello                                        Happier
# 107810      Pop      Sam Smith         Dancing With A Stranger (with Normani)
# 107875      Pop     Pedro Capó                                  Calma - Remix
# 9037      Dance        Ava Max                               Sweet but Psycho
# 9028      Dance         Halsey                                     Without Me
# 86953       Rap    Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 66643   Hip-Hop   Daddy Yankee                                      Con Calma
# 9026      Dance  Ariana Grande       break up with your girlfriend, i'm bored
# 86951       Rap    Post Malone                                           Wow.
# 9027      Dance  Ariana Grande                                        7 rings
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %%
def knnQuery(queryPoint, arrCharactPoints, k):
    tmp = arrCharactPoints.copy(deep=True)
    tmp['dist'] = tmp.apply(lambda x: np.linalg.norm(x-queryPoint), axis=1)
    tmp = tmp.sort_values('dist')
    return tmp.head(k).index

# %%
def querySimilars(df, columns, idx, func, param):
    arr = df[columns].copy(deep=True)
    queryPoint = arr.loc[idx]
    arr = arr.drop([idx])
    response = func(queryPoint, arr, param)
    return response

# %%
def getMusicName(elem):
    return '{} - {}'.format(elem['artist_name'], elem['track_name'])

# %%
row_num = spop[(spop['track_name'] == 'Rumour Has It') & (spop['artist_name'] == 'Adele')].index.to_numpy() 
songIndex = row_num[0] # query point, selected song
columns = ['acousticness','danceability','energy','instrumentalness','liveness','speechiness','valence']
# Selecting query parameters
func, param = knnQuery, 3 # k=3
# Querying
response = querySimilars(spop, columns, songIndex, func, param)

# %%
anySong = spop.loc[songIndex]
# Get the song name
anySongName = getMusicName(anySong)
# Print
print('#Query Point')
print(songIndex, anySongName)
# Out:
# #Query Point
# 110467 Adele - Rumour Has It

# %%
print('# Similar songs')
for idx in response:
    anySong = spop.loc[idx]
    anySongName = getMusicName(anySong)
    print(idx, anySongName)
# Out:
# # Similar songs
# 151312 Teddy Robb - Really Shouldn't Drink Around You
# 52609 Gina Sicilia - Man in the Sky
# 112439 Mamamoo - Starry Night

# %%
i=spop[spop['artist_name']=='Adele']
print(i)
# Out:
#        genre artist_name                            track_name  \
# 229830  Soul       Adele       Hometown Glory (Single Version)
# 193723  Soul       Adele                         Cold Shoulder
# 226572  Soul       Adele                               My Same
# 193642  Soul       Adele  Hometown Glory (High Contrast Remix)
# 193006  Soul       Adele                         Right As Rain
# 151652   Pop       Adele                     Sweetest Devotion
# 151406   Pop       Adele                           He Won't Go
# 193414  Soul       Adele                       Hiding My Heart
# 150579   Pop       Adele                Melt My Heart To Stone
# 150491   Pop       Adele                      Love in the Dark
# 192239  Soul       Adele                        Hometown Glory
# 113763   Pop       Adele                             River Lea
# 192813  Soul       Adele                   Rolling In The Deep
# 112228   Pop       Adele                     Million Years Ago
# ...

# %%
spop.head()
# Out:
#                    genre         artist_name  \
# 57661              Opera      Giuseppe Verdi
# 75611   Children's Music         Juice Music
# 74865   Children's Music         The Re-Bops
# 195239             Movie        Hayley Mills
# 76602   Children's Music  The Countdown Kids
#
#                                                track_name  \
# 57661   Macbeth, Act III: Ora di morte e di vendetta (...
# 75611                                       African Drums
# 74865                            You've Got What It Takes
# 195239                                Unfinished Business
# 76602                                      Be Without You
#
#                       track_id  popularity  acousticness  danceability  \
# 57661   1LpmLwZfwFj6GXXASoxVMI           0        0.9430         0.361
# 75611   77zegSnCBqSlnUK20d4Fqj           0        0.0413         0.728
# 74865   4RVa6LkTqHL6DjQleOwZwF           0        0.5690         0.680
# ...

# %%
def popularity_rec(df):
    x=df[['artist_name', 'track_name']].tail()
    print(x)
popularity_rec(spop)
# Out:
#          artist_name                                     track_name
# 86953    Post Malone  Sunflower - Spider-Man: Into the Spider-Verse
# 66643   Daddy Yankee                                      Con Calma
# 9026   Ariana Grande       break up with your girlfriend, i'm bored
# 86951    Post Malone                                           Wow.
# 9027   Ariana Grande                                        7 rings
